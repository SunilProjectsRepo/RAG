# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
os.environ["GEMINI_API_KEY"] = os.getenv("GEMINI_API_KEY")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-pro",
    temperature=0.3
)

# %%
llm
# Out:
# ChatGoogleGenerativeAI(profile={}, google_api_key=SecretStr('**********'), model='gemini-pro', temperature=0.3, client=<google.genai.client.Client object at 0x00000228E4653A50>, default_metadata=(), model_kwargs={})

# %% [markdown]
# ### Once we have the LLM models, everything else is same. We can use the vectorstore, RAG chain, etc...
