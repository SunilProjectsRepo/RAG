# %% [markdown]
# ### JSON Parsing and Processing

# %%
import json
import os

os.makedirs('data/json_files', exist_ok=True)

# %%
#Sample nested JSON data
json_data = {
    "company": "TechCorp",
    "employees": [
        {
            "id": 1,
            "name": "John Doe",
            "position": "Software Engineer",
            "skills": ["Python", "JavaScript", "React"],
            "projects": [
                {"name": "RAG System", "status": "In Progress"},
                {"name": "Data Pipeline", "status": "Completed"}
            ]
        },
        {
            "id": 2,
            "name": "Jane Smith",
            "position": "Data Scientist",
            "skills": ["Python", "SQL", "Machine Learning"],
            "projects": [
                {"name": "ML Model", "status": "In Progress"},
                {"name": "Analytics Dashboard", "status": "Planning"}
            ]
        }
    ],
    "departments": {
        "engineering": {
            "head": "Mike Johnson",
            "budget": 1000000,
            "team_size": 25
        },
        "data_science": {
            "head": "Sarah Williams",
            "budget": 750000,
            "team_size": 15
        }
    }
}

# %%
json_data
# Out:
# {'company': 'TechCorp',
#  'employees': [{'id': 1,
#    'name': 'John Doe',
#    'position': 'Software Engineer',
#    'skills': ['Python', 'JavaScript', 'React'],
#    'projects': [{'name': 'RAG System', 'status': 'In Progress'},
#     {'name': 'Data Pipeline', 'status': 'Completed'}]},
#   {'id': 2,
#    'name': 'Jane Smith',
#    'position': 'Data Scientist',
#    'skills': ['Python', 'SQL', 'Machine Learning'],
#    'projects': [{'name': 'ML Model', 'status': 'In Progress'},
#     {'name': 'Analytics Dashboard', 'status': 'Planning'}]}],
#  'departments': {'engineering': {'head': 'Mike Johnson',
#    'budget': 1000000,
#    'team_size': 25},
#   'data_science': {'head': 'Sarah Williams',
#    'budget': 750000,
#    'team_size': 15}}}

# %%
with open('data/json_files/company_data.json', 'w') as f:
    json.dump(json_data, f, indent=2)

# %%
# Save JSON Lines format
jsonl_data = [
    {"timestamp": "2024-01-01T10:00:00Z", "event": "user_login", "user_id": 123},
    {"timestamp": "2024-01-01T10:05:00Z", "event": "page_view", "user_id": 123, "page": "/home"},
    {"timestamp": "2024-04-01T10:10:00Z", "event": "purchase", "user_id": 123, "amount": 99.99}
]

with open('data/json_files/events.jsonl', 'w') as f:
    for item in jsonl_data:
        f.write(json.dumps(item) + '\n')

# %% [markdown]
# ### JSON Processing Strategies

# %%
from langchain_community.document_loaders import JSONLoader
import json

# %% [markdown]
# ### Method - JSONLoader with jq_schema

# %%
# Extract Employee Information
employee_loader = JSONLoader(
    file_path='data/json_files/company_data.json',
    jq_schema='.employees[]', # jq query to extract each employee
    text_content=False # Get full JSON objects
)

employee_docs = employee_loader.load()
print(f"Loaded {len(employee_docs)} employee documents.")
print(f"First employee: {employee_docs[0].page_content[:200]}...")
print(employee_docs)
# Out:
# Loaded 2 employee documents.
# First employee: {"id": 1, "name": "John Doe", "position": "Software Engineer", "skills": ["Python", "JavaScript", "React"], "projects": [{"name": "RAG System", "status": "In Progress"}, {"name": "Data Pipeline", "sta...
# [Document(metadata={'source': 'C:\\RAG\\DataIngestionParsing\\data\\json_files\\company_data.json', 'seq_num': 1}, page_content='{"id": 1, "name": "John Doe", "position": "Software Engineer", "skills": ["Python", "JavaScript", "React"], "projects": [{"name": "RAG System", "status": "In Progress"}, {"name": "Data Pipeline", "status": "Completed"}]}'), Document(metadata={'source': 'C:\\RAG\\DataIngestionParsing\\data\\json_files\\company_data.json', 'seq_num': 2}, page_content='{"id": 2, "name": "Jane Smith", "position": "Data Scientist", "skills": ["Python", "SQL", "Machine Learning"], "projects": [{"name": "ML Model", "status": "In Progress"}, {"name": "Analytics Dashboard", "status": "Planning"}]}')]

# %% [markdown]
# ### Method - Custom JSON Processing for complex structures

# %%
from typing import List
from langchain_core.documents import Document
from unstructured import documents

def process_json_intelligently(filepath: str) -> List[Document]:
    """Process JSON with intelligent flattening and context preservation"""
    with open(filepath, 'r') as f:
        data = json.load(f)

    documents = []

    # Strategy 1: Create documents for each employee with full context
    for emp in data.get('employees', []):
        content = f"""Employee Profile:
        Name: {emp['name']}
        Role: {emp['position']}
        Skills: {', '.join(emp['skills'])}

        Projects:"""
        for proj in emp.get('projects', []):
            content +=f"\n- {proj['name']} (Status: {proj['status']})"

        doc = Document(
            page_content=content,
            metadata={
                'source': filepath,
                'data_type': 'employee_profile',
                'employee_id': emp['id'],
                'employee_name': emp['name'],
                'role': emp['position']
            }
        )
        documents.append(doc)
    return documents

# %%
process_json_intelligently("data/json_files/company_data.json")
# Out:
# [Document(metadata={'source': 'data/json_files/company_data.json', 'data_type': 'employee_profile', 'employee_id': 1, 'employee_name': 'John Doe', 'role': 'Software Engineer'}, page_content='Employee Profile:\n        Name: John Doe\n        Role: Software Engineer\n        Skills: Python, JavaScript, React\n\n        Projects:\n- RAG System (Status: In Progress)\n- Data Pipeline (Status: Completed)'),
#  Document(metadata={'source': 'data/json_files/company_data.json', 'data_type': 'employee_profile', 'employee_id': 2, 'employee_name': 'Jane Smith', 'role': 'Data Scientist'}, page_content='Employee Profile:\n        Name: Jane Smith\n        Role: Data Scientist\n        Skills: Python, SQL, Machine Learning\n\n        Projects:\n- ML Model (Status: In Progress)\n- Analytics Dashboard (Status: Planning)')]
